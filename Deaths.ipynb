# %% [markdown]
# # Import

# %%
# %load_ext autoreload
# %autoreload 2
from DataProcessing import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Settings

# %%
selected_date = '2024-11'

# %% [markdown]
# # Death Data

# %%
df = generate_deathData()
df
# Out:
# patient death report2024-12-02 at 23_15_53.csv
# Carry forward death not in data: MR005769 2024-01
# Carry forward death not in data: MR000766 2024-01
# Patient attrition2024-12-02 at 12_01_28.csv
# GL Expiry Report New2024-12-02 at 15_25_14.csv
#        Region  Primary Center    MR No.    Patient Name W/O Title Death Date  \
# 0    Region 4   Batu Berendam  MR005550  THANAPAKIAM A/P MUNIANDY 2024-11-25
# 1    Region 1  Seberang Perai  MR008167       KHAZALI BIN MOHAMAD 2024-11-26
# 2    Region 1          Kangar  MR000348         ZORINA BINTI DESA 2024-11-21
# 3    Region 3             TTJ  MR007289     BAHARIPAH BINTI HUSIN 2024-11-21
# 4    Region 5           Papar  MR007483       JERI BIN JAMALUDDIN 2024-11-24
# ..        ...             ...       ...                       ...        ...
# 219  Region 3            Meru  MR005604         JAILANI BIN AHMAD 2024-01-02
# 220  Region 3            Meru  MR007196       MAT RAHIM BIN KASIM 2024-01-03
# 221  Region 2  Tanjung Karang  MR006211        MARPU BINTI SARNO  2024-01-07
# 222  Region 4     Kota Tinggi  MR001337       RUHANI BINTI YAAKOB 2024-01-01
# 223  Region 3        Seremban  MR000812      AMRAH BINTI MD YUSOF 2024-01-04
#
#     Death Time       Death Reason  \
# 0     11:25:00            Cardiac
# 1     08:25:00      Death at home
# 2     15:00:00             Others
# 3     21:39:00  Infection/ Sepsis
# 4     10:00:00               ESRD
# ..         ...                ...
# 219   09:30:00      Death at home
# 220   09:34:00        GI bleeding
# 221   10:30:00               ESRD
# 222   11:55:00            Cardiac
# 223   11:39:00             Others
#
#                             Physical Discharge Remarks        Death Category  \
# 0    cardiogenic shock secondary to non st elevatio...               Cardiac
# 1                                     CARDIAC, DM, HPT               Cardiac
# 2                Suddenly death at home,underlying CA.         Death at home
# 3             pt passed away at HTJ due to septicemia      Infection/ Sepsis
# 4                                                  NaN  ESRD (hyperK/ fluid)
# ..                                                 ...                   ...
# 219                                sakit buah pinggang         Death at home
# 220                                                NaN           GI bleeding
# 221  Death @ Hosp Tanjong Karang, with ? of chest i...  ESRD (hyperK/ fluid)
# 222                            Acute coronary syndrome               Cardiac
# 223  SEPTIC SHOCK SECONDARY TO HOSPITAL AQUIRED PNE...     Infection/ Sepsis
#
#      Discharging Doctor  Age    Month  Week  \
# 0                   NaN   72  2024-11    48
# 1                   NaN   68  2024-11    48
# 2                   NaN   59  2024-11    47
# 3                   NaN   71  2024-11    47
# 4                   NaN   64  2024-11    47
# ..                  ...  ...      ...   ...
# 219                 NaN   75  2024-01     1
# 220                 NaN   61  2024-01     1
# 221                 NaN   58  2024-01     1
# 222                 NaN   68  2024-01     1
# 223                 NaN   77  2024-01     1
#
#                                 Sponsor
# 0    MAJLIS BANDARAYA MELAKA BERSEJARAH
# 1                                   NaN
# 2        JABATAN HAL EHWAL VETERAN (BP)
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 219              LEMBAGA ZAKAT SELANGOR
# 220       PERTUBUHAN KESELAMATAN SOSIAL
# 221              LEMBAGA ZAKAT SELANGOR
# 222     MAJLIS AGAMA ISLAM NEGERI JOHOR
# 223  JABATAN PERKHIDMATAN AWAM MALAYSIA
#
# [224 rows x 14 columns]

# %% [markdown]
# # Death Count

# %% [markdown]
# ## Country

# %%
country_death = monthly_death_count(df)[0]
country_death
# Out:
#       Month  Count
# 0   2024-01     27
# 1   2024-02     17
# 2   2024-03     22
# 3   2024-04     28
# 4   2024-05     31
# 5   2024-06     24
# 6   2024-07     20
# 7   2024-08     12
# 8   2024-09     17
# 9   2024-10     11
# 10  2024-11     15

# %% [markdown]
# ## Region

# %%
region_death = monthly_death_count(df)[1]
region_death[region_death['Month'] == selected_date]
# Out:
#       Region    Month  Count
# 9   Region 1  2024-11      3
# 19  Region 2  2024-11      5
# 30  Region 3  2024-11      4
# 41  Region 4  2024-11      2
# 52  Region 5  2024-11      1

# %% [markdown]
# ## Center

# %%
center_death = monthly_death_count(df)[-1]
center_death[center_death['Month'] == selected_date]
# Out:
#        Region    Primary Center    Month  Count
# 1    Region 1        Alor Setar  2024-11      1
# 7    Region 1            Kangar  2024-11      1
# 18   Region 1    Seberang Perai  2024-11      1
# 34   Region 2  Batang Berjuntai  2024-11      1
# 40   Region 2            Kajang  2024-11      1
# 44   Region 2           Puchong  2024-11      1
# 59   Region 2      Sungai Besar  2024-11      1
# 65   Region 2    Tanjung Karang  2024-11      1
# 73   Region 3       Kuala Pilah  2024-11      1
# 95   Region 3               TTJ  2024-11      3
# 108  Region 4     Batu Berendam  2024-11      1
# 118  Region 4       Johor Bharu  2024-11      1
# 146  Region 5             Papar  2024-11      1

# %% [markdown]
# # Death Reason Count

# %% [markdown]
# ## Country

# %%
country_category = monthly_death_reason(df)[-1]
country_category[country_category['Month'] == selected_date]
# Out:
#        Region    Primary Center    Month        Death Category  Count  \
# 1    Region 1        Alor Setar  2024-11               Cardiac      1
# 8    Region 1            Kangar  2024-11         Death at home      1
# 20   Region 1    Seberang Perai  2024-11               Cardiac      1
# 41   Region 2  Batang Berjuntai  2024-11               Cardiac      1
# 48   Region 2            Kajang  2024-11  ESRD (hyperK/ fluid)      1
# 52   Region 2           Puchong  2024-11                Others      1
# 74   Region 2      Sungai Besar  2024-11  ESRD (hyperK/ fluid)      1
# 81   Region 2    Tanjung Karang  2024-11         Death at home      1
# 90   Region 3       Kuala Pilah  2024-11               Cardiac      1
# 117  Region 3               TTJ  2024-11       Cerebrovascular      1
# 118  Region 3               TTJ  2024-11     Infection/ Sepsis      2
# 135  Region 4     Batu Berendam  2024-11               Cardiac      1
# 148  Region 4       Johor Bharu  2024-11               Cardiac      1
# 184  Region 5             Papar  2024-11  ESRD (hyperK/ fluid)      1
#
#      Percentage
# 1        100.00
# 8        100.00
# 20       100.00
# 41       100.00
# 48       100.00
# 52       100.00
# 74       100.00
# 81       100.00
# 90       100.00
# 117       33.33
# 118       66.67
# 135      100.00
# 148      100.00
# 184      100.00
