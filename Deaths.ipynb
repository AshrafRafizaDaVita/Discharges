# %% [markdown]
# # Import

# %%
# %load_ext autoreload
# %autoreload 2
from DataProcessing import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Read Mortality Report

# %%
df = combine_report()
df
# Out:
# patient death report2024-12-02 at 11_41_10.csv
# Carry forward death not in data: MR005769 2024-01
# Carry forward death not in data: MR000766 2024-01
# Patient attrition2024-12-02 at 12_01_28.csv
# GL Expiry Report New2024-12-02 at 15_25_14.csv
#        MR No.    Patient Name W/O Title Death Date Death Time  \
# 0    MR005550  THANAPAKIAM A/P MUNIANDY 2024-11-25   11:25:00
# 1    MR008167       KHAZALI BIN MOHAMAD 2024-11-26   08:25:00
# 2    MR000348         ZORINA BINTI DESA 2024-11-21   15:00:00
# 3    MR007289     BAHARIPAH BINTI HUSIN 2024-11-21   21:39:00
# 4    MR007483       JERI BIN JAMALUDDIN 2024-11-24   10:00:00
# ..        ...                       ...        ...        ...
# 218  MR005604         JAILANI BIN AHMAD 2024-01-02   09:30:00
# 219  MR007196       MAT RAHIM BIN KASIM 2024-01-03   09:34:00
# 220  MR006211        MARPU BINTI SARNO  2024-01-07   10:30:00
# 221  MR001337       RUHANI BINTI YAAKOB 2024-01-01   11:55:00
# ...

# %%
df['Status'].unique()
# Out:
# array(['Active'], dtype=object)
