# %% [markdown]
# # Import

# %%
# %load_ext autoreload
# %autoreload 2
from DataProcessing import *

# %% [markdown]
# # Read Mortality Report

# %%
df = readMortality()
df
# Out:
# patient death report2024-12-02 at 11_41_10.csv
# Carry forward death not in data: MR005769 2024-01
# Carry forward death not in data: MR000766 2024-01
# Patient attrition2024-12-02 at 12_01_28.csv
#        MR No.    Patient Name W/O Title Death Date Death Time  \
# 0    MR005550  THANAPAKIAM A/P MUNIANDY 2024-11-25   11:25:00
# 1    MR008167       KHAZALI BIN MOHAMAD 2024-11-26   08:25:00
# 2    MR000348         ZORINA BINTI DESA 2024-11-21   15:00:00
# 3    MR007289     BAHARIPAH BINTI HUSIN 2024-11-21   21:39:00
# 4    MR007483       JERI BIN JAMALUDDIN 2024-11-24   10:00:00
# ..        ...                       ...        ...        ...
# 217  MR005604         JAILANI BIN AHMAD 2024-01-02   09:30:00
# 218  MR007196       MAT RAHIM BIN KASIM 2024-01-03   09:34:00
# 219  MR006211        MARPU BINTI SARNO  2024-01-07   10:30:00
# 220  MR001337       RUHANI BINTI YAAKOB 2024-01-01   11:55:00
# 221  MR000812      AMRAH BINTI MD YUSOF 2024-01-04   11:39:00
#
# ...

# %%
df.columns
# Out:
# Index(['MR No.', 'Duplicate MR No.', 'Patient Name W/O Title',
#        'Discharge Type', 'Death Date', 'Death Time', 'Death Reason',
#        'Physical Discharge Remarks', 'Discharging Doctor', 'Primary Center',
#        'Date of Birth', 'Age', 'Gender', 'National/Passport ID Type',
#        'National/Passport ID [NRIC: ******-**-****][Police ID: RF/******][Army ID: T*******]',
#        'First Dialysis Date in Davita', 'First Dialysis Date(FDODD)',
#        'Virology Status Date', 'Virology Status', 'Blood Group',
#        'PDPA Consent (Yes/No)', 'Patient Sources',
#        'Patient Referral Source Hospital', 'Religion', 'Address', 'Region',
#        'Month', 'Week'],
#       dtype='object')
