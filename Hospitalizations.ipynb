# %%
# %load_ext autoreload
# %autoreload 2
from DataProcessing import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = gen_HospitalizationData()
df = genHnM(df)

df
# Out:
# Hospitalization Information Report2024-12-10 at 10_02_58.csv
# c:\Users\mrafiza\Documents\My Workspace\Programming\Discharges\DataProcessing.py:306: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Admission Date'] = df['Addmission Date'].dt.strftime('%d/%m/%Y')
#     Primary Center    MR No. Admission Date Discharge Date   LOS  \
# 0            Tulip  MR000052     16/11/2024     2024-11-17   1.0
# 1      Wangsa Maju  MR000124     05/11/2024     2024-11-17  12.0
# 2           Rawang  MR000142     01/11/2024     2024-11-03   2.0
# 3            Gurun  MR000405     21/11/2024     2024-12-03  12.0
# 4            Bangi  MR000509     09/11/2024     2024-12-01  22.0
# ..             ...       ...            ...            ...   ...
# ...

# %%
df['Reason'].unique()
# Out:
# array(['Infection: Others (viral, dengue, zoster TB etc)',
#        'Infection : Access', 'Others', 'Surgery',
#        'Cardio/cerebrovascular', 'Infection: Non- Access',
#        'Fluid overload',
#        'Access Complications (thrombosis/bleeding/dislodge)', 'Anaemia',
#        'Access Creation/repair(surgery/plasy/fistulogram/change',
#        'GI related ( constipation, diarrhea, bleed)'], dtype=object)
